# %%
cd ..
# Out:
# m:\OneDrive\Projects\federated_imputation_pc1

# %% [markdown]
# ## Loading

# %%
# %load_ext autoreload
# %autoreload
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from src.modules.data_spliting import split_train_test
from src.modules.data_preprocessing import load_data
import random
from src.modules.data_partition import data_partition
from src.fed_imp.sub_modules.missing_simulate.missing_adder_new import add_missing
from src.fed_imp.sub_modules.client.client_factory import ClientsFactory
from src.fed_imp.sub_modules.strategy.strategy_imp import StrategyImputation
from src.fed_imp.sub_modules.server.load_server import load_server
from src.fed_imp.sub_modules.client.simple_client import SimpleClient
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from dython.nominal import correlation_ratio
import missingno as msno

# %%
def visualize_ms(clients_ms_datas:list, sort_patterns: bool = False):
    n_cols = 5
    n_clients = len(clients_ms_datas)
    n_rows = (n_clients + 4)//n_cols

    fig, axes = plt.subplots(n_rows, n_cols, figsize=(n_cols*4, n_rows*3), squeeze=False)
    for i in range(n_clients):
        ax = axes[i//n_cols, i%n_cols]
        d = pd.DataFrame(clients_ms_datas[i])
        d = d.sort_values(by=d.columns[-1])
        if sort_patterns:
            msno.matrix(d, ax=ax, sparkline=False, sort='ascending')
        else:
            msno.matrix(d, ax=ax, sparkline=False)
        ax.set_title('Client {}'.format(i))
    plt.tight_layout()

def correlation(original_data, centralized_data):
    original_df = pd.DataFrame(original_data)
    target_col = original_df.columns[-1]
    correlation_ret = original_df.corrwith(original_df[target_col], method=correlation_ratio).sort_values(ascending=False)
    print(correlation_ret)

    centralized_df = pd.DataFrame(centralized_data)
    target_col = centralized_df.columns[-1]
    correlation_ret = centralized_df.corrwith(original_df[target_col], method=correlation_ratio).sort_values(ascending=False)
    print(correlation_ret)

def run_pred(clf_name, X_train, y_train, X_test, y_test):
    accus = []
    for i in range(5):
        seed = 21 + i*93940
        if clf_name == 'LR':
            clf = LogisticRegression(random_state=seed, max_iter=1000)
        elif clf_name == 'MLP':
            clf = MLPClassifier(
                [32, 32], batch_size = 128, random_state=seed, alpha = 0.001, max_iter = 1000)
        else:
            raise ValueError('clf_name should be LR or MLP')
        clf.fit(X_train, y_train)
        y_pred = clf.predict(X_test)
        accus.append(metrics.accuracy_score(y_test, y_pred))
    return np.mean(accus), np.std(accus)

def sklearn_evaluation(rets):

    original_data = rets['data']['origin_data'].reshape(-1, rets['data']['origin_data'].shape[-1])
    centralized_data = rets['data']['imputed_data'].reshape(-1, rets['data']['origin_data'].shape[-1])
    test_data = rets['data']['test_data']

    X_train = centralized_data[:, :-1]
    y_train = centralized_data[:, -1]
    X_test = test_data[:, :-1]
    y_test = test_data[:, -1]
    accu, std = run_pred('MLP', X_train, y_train, X_test, y_test)
    print("Accuracy imputed centralized MLP:{:.4f} ({:.3f})".format(accu, std))

    accu, std = run_pred('LR', X_train, y_train, X_test, y_test)
    print("Accuracy imputed centralized LR:{:.4f} ({:.3f})".format(accu, std))

    X_train = original_data[:, :-1]
    y_train = original_data[:, -1]
    X_test = test_data[:, :-1]
    y_test = test_data[:, -1]
    accu, std = run_pred('MLP', X_train, y_train, X_test, y_test)
    print("Accuracy orignal centralized MLP:{:.4f} ({:.3f})".format(accu, std))

    accu, std = run_pred('LR', X_train, y_train, X_test, y_test)
    print("Accuracy orignal centralized MLP:{:.4f} ({:.3f})".format(accu, std))

# %%
experiment_config_template = {
  "num_clients": 20,
  "data": {
    "dataset_name": "ijcnn_balanced_pca",
    "normalize": True
  },
  "data_partition": {
    "strategy": "sample@p=0.01",
    "params": {}
  },
  "missing_simulate": {
    "mr_strategy": "fixed",
    "mf_strategy": "all",
    "mm_strategy": "mary_lr"
  },
  "imputation": {
    "initial_strategy_num": "mean",
    "initial_strategy_cat": "mode",
    "estimator_num": "ridge_cv",
    "estimator_cat": "logistic_cv",
    "imp_evaluation_model": "logistic",
    "imp_evaluation_params": {
      "tune_params": "gridsearch"
    },
    "clip": False
  },
  "agg_strategy_imp": {
    "strategy": "fedavg-s",
    "params": {
      "ms_field": "missing_cell_pct",
      "beta": 0.7
    }
  },
  "server_type": "fedavg_pytorch",
  "server": {
    "impute_mode": "instant",
    "imp_round": 20,
    "imp_local_epochs": 0,
    "pred_round": 0,
    "pred_local_epochs": 0,
    "model_fit_mode": "one_shot"
  },
  "pred_model": {
    "model_params": {
      "model": "2nn",
      "num_hiddens": 128,
      "model_init_config": None,
      "model_other_params": None
    },
    "train_params": {
      "batch_size": 128,
      "learning_rate": 0.001,
      "weight_decay": 0.0001,
      "pred_round": 200,
      "pred_local_epochs": 3
    }
  },
  "experiment": {
    "n_rounds": 1,
    "seed": 102931466,
    "mtp": False,
    "random_seed": 50,
    "num_process": 3,
    "test_size": 0.1,
    "track": True
  },
  "tune_params": False,
  "track": False,
  "tune_params": True,
  "prediction": False,
  "save_state": False,
  "test_size": 0.1,
  "algo_params": {
    "local": {},
    "fedavg-s": {},
    "fedwavg": {
      "alpha": 0.9
    },
    "fedmechw": {
      "client_thres": 1.0,
      "alpha": 0.8,
      "beta": 0.15
    },
    "fedmechclw": {
      "client_thres": 0.2,
      "thres1": 0.2,
      "alpha": 0.5
    },
    'testavg':{
        
    },
    'testavg2':{
        
    },
    "scale_factor": 4
  }
}

# %%
server_config_tmpl = {
    "server_name": 'fedavg_mlp_pytorch_pred',
    "server_pred_config": {
        "model_params": {
            "model": "2nn",
            "num_hiddens": 32,
            "model_init_config": None,
            "model_other_params": None
        },
        "train_params": {
            "batch_size": 128,
            "learning_rate": 0.001,
            "weight_decay": 0.001,
            "pred_round": 1000,
            "pred_local_epochs": 5,
            'local_epoch': 5,
            'sample_pct': 1
        }
    },
    "server_config": {
        'pred_rounds': 1,
        'seed': 21
    }
}

# %% [markdown]
# ## MNAR LR

# %%
config2 = experiment_config_template.copy()
config2['data']['dataset_name'] = 'statlog'
config2['num_clients'] = 20
config2['missing_simulate']['mr_strategy'] = 'fixed@mr=0.5'
config2['missing_simulate']['mf_strategy'] = 'all'
config2['missing_simulate']['mm_strategy'] = 'mnar_lr@sp=extreme'
config2['data_partition']['strategy'] = 'sample@p=0.01'
config2['agg_strategy_imp']['strategy'] = 'fedavg-s'

configuration = config2
num_clients = configuration['num_clients']
# set random seed
seed = configuration['experiment']['seed']
mtp = configuration['experiment']['mtp']
tune_params = configuration['tune_params']
random.seed(seed)  # seed for split data

# load data
dataset_params = configuration['data']
data, data_config = load_data(**dataset_params)
regression = data_config['task_type'] == 'regression'

n_rounds = configuration['experiment']['n_rounds']
test_size = configuration['experiment'].get('test_size', 0.1)
if n_rounds == 1:
    n_rounds_data = split_train_test(data, n_folds=2, seed=seed, test_size=test_size, regression=regression)
else:
    n_rounds_data = split_train_test(
        data, n_folds=n_rounds, seed=seed, test_size=test_size, regression=regression
        )

# n rounds average
train_data, test_data = n_rounds_data[0]

new_seed = (seed + 10087 * 0) % (2 ^ 23)
regression = data_config['task_type'] == 'regression'
data_partition_params = configuration['data_partition']
data_partitions = data_partition(
    **data_partition_params, data=train_data.values, n_clients=num_clients, seed=new_seed,
    regression=regression
)
missing_params = configuration['missing_simulate']
cols = np.arange(0, train_data.shape[1] - 1)
scenario = missing_params
data_ms_clients2 = add_missing(
    train_data_list=data_partitions, scenario=scenario, cols=cols, seed=new_seed
)

client_factory = ClientsFactory(debug=False)
clients = client_factory.generate_clients(
    num_clients, data_partitions, data_ms_clients2, test_data.values, data_config,
    configuration['imputation'], seed=new_seed
)
visualize_ms(data_ms_clients2)
# Out:
# sample {'p': '0.01'}
# ['mnar_quantile_left' 'mnar_quantile_left' 'mnar_quantile_right'
#  'mnar_quantile_right' 'mnar_quantile_right' 'mnar_quantile_right'
#  'mnar_quantile_right' 'mnar_quantile_right' 'mnar_quantile_right'
#  'mnar_quantile_right' 'mnar_quantile_right' 'mnar_quantile_right'
#  'mnar_quantile_right' 'mnar_quantile_right' 'mnar_quantile_right'
#  'mnar_quantile_right' 'mnar_quantile_right' 'mnar_quantile_right'
#  'mnar_quantile_right' 'mnar_quantile_right']

# %% [markdown]
# ### Simple Averaging

# %%
configuration['agg_strategy_imp']['strategy'] = 'fedavg-s'
configuration['server_type'] = 'fedavg_pytorch'
configuration['prediction'] = False
configuration['save_state'] = True
configuration['track'] = True

# Create Imputation Strategy
imp_strategy = configuration['agg_strategy_imp']['strategy']
params = configuration['algo_params'][imp_strategy]

strategy_imp = StrategyImputation(strategy=imp_strategy, params=params)

# Create Server
server_type = configuration['server_type']
server_config = configuration['server']
server_config["n_cols"] = test_data.shape[1] - 1

pred_config = configuration['pred_model']
pred_config['model_params']['input_feature_dim'] = test_data.shape[1] - 1
pred_config['model_params']['output_classes_dim'] = len(np.unique(test_data.iloc[:, -1].values))

server = load_server(
    server_type,
    clients=clients,
    strategy_imp=strategy_imp,
    server_config=server_config,
    pred_config=pred_config,
    test_data=test_data.values,
    seed=new_seed,
    track=configuration['track'],
    run_prediction=configuration['prediction'],
    persist_data=configuration['save_state'],
)

# return server
ret2 = server.run()
# Out:
# 2023-07-19 12:18:27.425 | INFO     | src.fed_imp.sub_modules.server.base_server:run:155 - FL finished in 48.53576190001331

# %%
x = list(range(len(ret2['client_imp_history'])))
client_ids = list(ret2['client_imp_history'][0][2]['metrics'].keys())

fig, ax = plt.subplots(1, 1, figsize=(10, 5))
for client_id in client_ids:
    y = [ret2['client_imp_history'][i][2]['metrics'][client_id]['imp@rmse'] for i in x]
    ax.plot(x, y, label=client_id)
plt.show()

# %%
sklearn_evaluation(ret2)
# Out:
# Accuracy imputed centralized MLP:0.9637 (0.003)
# Accuracy imputed centralized LR:0.9637 (0.000)
# Accuracy orignal centralized MLP:0.9895 (0.004)
# Accuracy orignal centralized MLP:0.9659 (0.000)

# %%
clients_ = {}
data_imp = ret2['data']['imputed_data']
missing_mask = ret2['data']['missing_mask']
data_true = ret2['data']['origin_data']
n_clients = ret2['data']['origin_data'].shape[0]
test_data = ret2['data']['test_data']
for client_id in range(n_clients):
    clients_[client_id] = SimpleClient(
        client_id=client_id,
        data_imp=data_imp[client_id],
        missing_mask=missing_mask[client_id],
        data_true=data_true[client_id],
        data_test=test_data
    )

pred_config = server_config_tmpl.copy()
server_name = 'fedavg_mlp_pytorch_pred'
server_pred_config = pred_config['server_pred_config']
server_pred_config['train_params']['pred_round'] = 1000
server_config = pred_config['server_config']
server_ = load_server(
        server_name, clients=clients_, server_config=server_config, pred_config=server_pred_config,
        test_data=test_data
    )

pred_ret2 = server.prediction()
# Out:
# 2023-07-19 09:28:36.629 | INFO     | src.fed_imp.sub_modules.server.server_fedavg:prediction:154 - Round: 50, test_accu: 0.7662, test_f1: 0.7657, val_loss: 0.6019, val_accu: 0.6462, val_f1: 0.6455
# 2023-07-19 09:29:03.612 | INFO     | src.fed_imp.sub_modules.server.server_fedavg:prediction:154 - Round: 100, test_accu: 0.7636, test_f1: 0.7635, val_loss: 0.5723, val_accu: 0.6654, val_f1: 0.6651
# 2023-07-19 09:29:29.434 | INFO     | src.fed_imp.sub_modules.server.server_fedavg:prediction:154 - Round: 150, test_accu: 0.7690, test_f1: 0.7689, val_loss: 0.5644, val_accu: 0.6673, val_f1: 0.6672
# 2023-07-19 09:29:55.311 | INFO     | src.fed_imp.sub_modules.server.server_fedavg:prediction:154 - Round: 200, test_accu: 0.7784, test_f1: 0.7784, val_loss: 0.5641, val_accu: 0.6692, val_f1: 0.6687

# %% [markdown]
# ### Complementary Models

# %%
config2 = experiment_config_template.copy()
config2['data']['dataset_name'] = 'statlog'
config2['num_clients'] = 20
config2['missing_simulate']['mr_strategy'] = 'fixed@mr=0.5'
config2['missing_simulate']['mf_strategy'] = 'all'
config2['missing_simulate']['mm_strategy'] = 'mnar_lr@sp=extreme'
config2['data_partition']['strategy'] = 'sample@p=0.01'
config2['agg_strategy_imp']['strategy'] = 'testavg2'

configuration = config2
num_clients = configuration['num_clients']
# set random seed
seed = configuration['experiment']['seed']
mtp = configuration['experiment']['mtp']
tune_params = configuration['tune_params']
random.seed(seed)  # seed for split data

# load data
dataset_params = configuration['data']
data, data_config = load_data(**dataset_params)
regression = data_config['task_type'] == 'regression'

n_rounds = configuration['experiment']['n_rounds']
test_size = configuration['experiment'].get('test_size', 0.1)
if n_rounds == 1:
    n_rounds_data = split_train_test(data, n_folds=2, seed=seed, test_size=test_size, regression=regression)
else:
    n_rounds_data = split_train_test(
        data, n_folds=n_rounds, seed=seed, test_size=test_size, regression=regression
        )

# n rounds average
train_data, test_data = n_rounds_data[0]

new_seed = (seed + 10087 * 0) % (2 ^ 23)
regression = data_config['task_type'] == 'regression'
data_partition_params = configuration['data_partition']
data_partitions = data_partition(
    **data_partition_params, data=train_data.values, n_clients=num_clients, seed=new_seed,
    regression=regression
)
missing_params = configuration['missing_simulate']
cols = np.arange(0, train_data.shape[1] - 1)
scenario = missing_params
data_ms_clients2 = add_missing(
    train_data_list=data_partitions, scenario=scenario, cols=cols, seed=new_seed
)

client_factory = ClientsFactory(debug=False)
clients = client_factory.generate_clients(
    num_clients, data_partitions, data_ms_clients2, test_data.values, data_config,
    configuration['imputation'], seed=new_seed
)
# Out:
# sample {'p': '0.01'}
# ['mnar_quantile_left' 'mnar_quantile_left' 'mnar_quantile_right'
#  'mnar_quantile_right' 'mnar_quantile_right' 'mnar_quantile_right'
#  'mnar_quantile_right' 'mnar_quantile_right' 'mnar_quantile_right'
#  'mnar_quantile_right' 'mnar_quantile_right' 'mnar_quantile_right'
#  'mnar_quantile_right' 'mnar_quantile_right' 'mnar_quantile_right'
#  'mnar_quantile_right' 'mnar_quantile_right' 'mnar_quantile_right'
#  'mnar_quantile_right' 'mnar_quantile_right']

# %%
configuration['agg_strategy_imp']['strategy'] = 'testavg2'
configuration['server_type'] = 'fedavg_pytorch'
configuration['prediction'] = False
configuration['save_state'] = True
configuration['track'] = True

# Create Imputation Strategy
imp_strategy = configuration['agg_strategy_imp']['strategy']
params = configuration['algo_params'][imp_strategy]

strategy_imp = StrategyImputation(strategy=imp_strategy, params=params)

# Create Server
server_type = configuration['server_type']
server_config = configuration['server']
server_config["n_cols"] = test_data.shape[1] - 1

pred_config = configuration['pred_model']
pred_config['model_params']['input_feature_dim'] = test_data.shape[1] - 1
pred_config['model_params']['output_classes_dim'] = len(np.unique(test_data.iloc[:, -1].values))

server = load_server(
    server_type,
    clients=clients,
    strategy_imp=strategy_imp,
    server_config=server_config,
    pred_config=pred_config,
    test_data=test_data.values,
    seed=new_seed,
    track=configuration['track'],
    run_prediction=configuration['prediction'],
    persist_data=configuration['save_state'],
)

# return server
ret4 = server.run()
# Out:
# testavg2
# 2023-07-19 12:19:48.471 | INFO     | src.fed_imp.sub_modules.server.base_server:run:155 - FL finished in 39.056601299962495

# %%
x = list(range(len(ret4['client_imp_history'])))
client_ids = list(ret4['client_imp_history'][0][2]['metrics'].keys())

fig, ax = plt.subplots(1, 1, figsize=(10, 5))
for client_id in client_ids:
    y = [ret4['client_imp_history'][i][2]['metrics'][client_id]['imp@rmse'] for i in x]
    ax.plot(x, y, label=client_id)
plt.show()

original_data4 = ret4['data']['origin_data'].reshape(-1, ret4['data']['origin_data'].shape[-1])
print(original_data4.shape)
centralized_data4 = ret4['data']['imputed_data'].reshape(-1, ret4['data']['imputed_data'].shape[-1])
print(centralized_data4.shape)
test_data4 = ret4['data']['test_data']
print(test_data4.shape)
ret4['imp_result']
# Out:
# (3420, 10)
# (3420, 10)
# (7302, 10)
# {'imp@rmse': 0.05410954373050956,
#  'imp@ws': 0.09635968998215962,
#  'imp@sliced_ws': 0.020216843190814203}

# %%
sklearn_evaluation(ret4)
# Out:
# Accuracy imputed centralized MLP:0.8541 (0.017)
# Accuracy imputed centralized LR:0.8467 (0.000)
# Accuracy orignal centralized MLP:0.9335 (0.003)
# Accuracy orignal centralized MLP:0.8711 (0.000)

# %%
clients_ = {}
data_imp2 = ret4['data']['imputed_data']
missing_mask2 = ret4['data']['missing_mask']
data_true2 = ret4['data']['origin_data']
n_clients = ret4['data']['origin_data'].shape[0]
for client_id in range(n_clients):
    clients_[client_id] = SimpleClient(
        client_id=client_id,
        data_imp=data_imp2[client_id],
        missing_mask=missing_mask2[client_id],
        data_true=data_true2[client_id],
        data_test=test_data4
    )

pred_config = server_config_tmpl.copy()
server_name = 'fedavg_mlp_pytorch_pred'
server_pred_config = pred_config['server_pred_config']
server_pred_config['train_params']['pred_round'] = 1000
server_config = pred_config['server_config']
server_ = load_server(
        server_name, clients=clients_, server_config=server_config, pred_config=server_pred_config,
        test_data=test_data4
    )

pred_ret2 = server_.prediction()
# Out:
# 2023-07-19 02:52:00.793 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 50, test_accu: 0.8297, test_f1: 0.8296, val_loss: 0.5619, val_accu: 0.7192, val_f1: 0.7187
# 2023-07-19 02:53:38.154 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 100, test_accu: 0.8409, test_f1: 0.8409, val_loss: 0.5360, val_accu: 0.7330, val_f1: 0.7328
# 2023-07-19 02:55:16.488 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 150, test_accu: 0.8520, test_f1: 0.8519, val_loss: 0.5298, val_accu: 0.7394, val_f1: 0.7394
# 2023-07-19 02:56:53.952 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 200, test_accu: 0.8548, test_f1: 0.8546, val_loss: 0.5265, val_accu: 0.7401, val_f1: 0.7401
# 2023-07-19 02:58:31.282 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 250, test_accu: 0.8617, test_f1: 0.8616, val_loss: 0.5242, val_accu: 0.7407, val_f1: 0.7407
# 2023-07-19 03:00:07.998 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 300, test_accu: 0.8663, test_f1: 0.8662, val_loss: 0.5225, val_accu: 0.7426, val_f1: 0.7426
# 2023-07-19 03:01:48.314 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 350, test_accu: 0.8701, test_f1: 0.8700, val_loss: 0.5210, val_accu: 0.7413, val_f1: 0.7413
# 2023-07-19 03:03:28.826 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 400, test_accu: 0.8731, test_f1: 0.8730, val_loss: 0.5197, val_accu: 0.7404, val_f1: 0.7404
# 2023-07-19 03:05:08.153 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 450, test_accu: 0.8762, test_f1: 0.8760, val_loss: 0.5188, val_accu: 0.7417, val_f1: 0.7416
# 2023-07-19 03:06:47.895 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 500, test_accu: 0.8780, test_f1: 0.8778, val_loss: 0.5180, val_accu: 0.7417, val_f1: 0.7415
# 2023-07-19 03:08:29.265 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 550, test_accu: 0.8798, test_f1: 0.8796, val_loss: 0.5169, val_accu: 0.7417, val_f1: 0.7416
# 2023-07-19 03:10:10.890 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 600, test_accu: 0.8799, test_f1: 0.8797, val_loss: 0.5158, val_accu: 0.7426, val_f1: 0.7426
# 2023-07-19 03:11:52.139 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 650, test_accu: 0.8811, test_f1: 0.8809, val_loss: 0.5149, val_accu: 0.7439, val_f1: 0.7439
# 2023-07-19 03:13:30.417 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 700, test_accu: 0.8827, test_f1: 0.8825, val_loss: 0.5143, val_accu: 0.7442, val_f1: 0.7441
# 2023-07-19 03:15:08.999 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 750, test_accu: 0.8841, test_f1: 0.8839, val_loss: 0.5134, val_accu: 0.7465, val_f1: 0.7464
# 2023-07-19 03:16:48.148 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 800, test_accu: 0.8853, test_f1: 0.8851, val_loss: 0.5126, val_accu: 0.7452, val_f1: 0.7451
# 2023-07-19 03:18:25.778 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 850, test_accu: 0.8862, test_f1: 0.8860, val_loss: 0.5119, val_accu: 0.7439, val_f1: 0.7438
# 2023-07-19 03:20:03.624 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 900, test_accu: 0.8867, test_f1: 0.8865, val_loss: 0.5112, val_accu: 0.7462, val_f1: 0.7460
# 2023-07-19 03:21:41.315 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 950, test_accu: 0.8882, test_f1: 0.8880, val_loss: 0.5107, val_accu: 0.7481, val_f1: 0.7479
# 2023-07-19 03:23:19.078 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 1000, test_accu: 0.8894, test_f1: 0.8892, val_loss: 0.5101, val_accu: 0.7487, val_f1: 0.7486
# 2023-07-19 03:23:19.079 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:164 - model1 test acc: 0.889784 (0.000), test f1: 0.889605 (0.000)

# %% [markdown]
# ### Our Method

# %%
config2 = experiment_config_template.copy()
config2['data']['dataset_name'] = 'statlog'
config2['num_clients'] = 20
config2['missing_simulate']['mr_strategy'] = 'fixed@mr=0.5'
config2['missing_simulate']['mf_strategy'] = 'all'
config2['missing_simulate']['mm_strategy'] = 'mnar_lr@sp=extreme'
config2['data_partition']['strategy'] = 'sample@p=0.01'
config2['agg_strategy_imp']['strategy'] = 'fedmechw'

configuration = config2
num_clients = configuration['num_clients']
# set random seed
seed = configuration['experiment']['seed']
mtp = configuration['experiment']['mtp']
tune_params = configuration['tune_params']
random.seed(seed)  # seed for split data

# load data
dataset_params = configuration['data']
data, data_config = load_data(**dataset_params)
regression = data_config['task_type'] == 'regression'

n_rounds = configuration['experiment']['n_rounds']
test_size = configuration['experiment'].get('test_size', 0.1)
if n_rounds == 1:
    n_rounds_data = split_train_test(data, n_folds=2, seed=seed, test_size=test_size, regression=regression)
else:
    n_rounds_data = split_train_test(
        data, n_folds=n_rounds, seed=seed, test_size=test_size, regression=regression
        )

# n rounds average
train_data, test_data = n_rounds_data[0]

new_seed = (seed + 10087 * 0) % (2 ^ 23)
regression = data_config['task_type'] == 'regression'
data_partition_params = configuration['data_partition']
data_partitions = data_partition(
    **data_partition_params, data=train_data.values, n_clients=num_clients, seed=new_seed,
    regression=regression
)
missing_params = configuration['missing_simulate']
cols = np.arange(0, train_data.shape[1] - 1)
scenario = missing_params
data_ms_clients2 = add_missing(
    train_data_list=data_partitions, scenario=scenario, cols=cols, seed=new_seed
)

client_factory = ClientsFactory(debug=False)
clients = client_factory.generate_clients(
    num_clients, data_partitions, data_ms_clients2, test_data.values, data_config,
    configuration['imputation'], seed=new_seed
)
# Out:
# sample {'p': '0.01'}
# ['mnar_quantile_left' 'mnar_quantile_left' 'mnar_quantile_right'
#  'mnar_quantile_right' 'mnar_quantile_right' 'mnar_quantile_right'
#  'mnar_quantile_right' 'mnar_quantile_right' 'mnar_quantile_right'
#  'mnar_quantile_right' 'mnar_quantile_right' 'mnar_quantile_right'
#  'mnar_quantile_right' 'mnar_quantile_right' 'mnar_quantile_right'
#  'mnar_quantile_right' 'mnar_quantile_right' 'mnar_quantile_right'
#  'mnar_quantile_right' 'mnar_quantile_right']

# %%
configuration['agg_strategy_imp']['strategy'] = 'fedmechw'
configuration['server_type'] = 'fedavg_pytorch'
configuration['prediction'] = False
configuration['save_state'] = True
configuration['track'] = True
configuration['algo_params']["fedmechw"] = {
    "client_thres": 0.4,
    "alpha": 1.0,
    "beta": 0
}

# Create Imputation Strategy
imp_strategy = configuration['agg_strategy_imp']['strategy']
params = configuration['algo_params'][imp_strategy]

strategy_imp = StrategyImputation(strategy=imp_strategy, params=params)

# Create Server
server_type = configuration['server_type']
server_config = configuration['server']
server_config["n_cols"] = test_data.shape[1] - 1

pred_config = configuration['pred_model']
pred_config['model_params']['input_feature_dim'] = test_data.shape[1] - 1
pred_config['model_params']['output_classes_dim'] = len(np.unique(test_data.iloc[:, -1].values))

server = load_server(
    server_type,
    clients=clients,
    strategy_imp=strategy_imp,
    server_config=server_config,
    pred_config=pred_config,
    test_data=test_data.values,
    seed=new_seed,
    track=configuration['track'],
    run_prediction=configuration['prediction'],
    persist_data=configuration['save_state'],
)

# return server
ret9 = server.run()
# Out:
# 2023-07-19 12:20:28.615 | INFO     | src.fed_imp.sub_modules.server.base_server:run:155 - FL finished in 39.54241239995463

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
for client_id in client_ids:
    y = [ret9['client_imp_history'][i][2]['metrics'][client_id]['imp@rmse'] for i in x]
    ax.plot(x, y, label=client_id)
plt.show()

original_data9 = ret9['data']['origin_data'].reshape(-1, ret9['data']['origin_data'].shape[-1])
print(original_data9.shape)
centralized_data9 = ret9['data']['imputed_data'].reshape(-1, ret9['data']['imputed_data'].shape[-1])
print(centralized_data4.shape)
test_data9 = ret9['data']['test_data']
print(test_data9.shape)
ret9['imp_result']
# Out:
# (3420, 10)
# (3420, 10)
# (7302, 10)
# {'imp@rmse': 0.05499742667214554,
#  'imp@ws': 0.10018922156705765,
#  'imp@sliced_ws': 0.02147710899571471}

# %%
sklearn_evaluation(ret9)
# Out:
# Accuracy imputed centralized MLP:0.8113 (0.026)
# Accuracy imputed centralized LR:0.8176 (0.000)
# Accuracy orignal centralized MLP:0.9335 (0.003)
# Accuracy orignal centralized MLP:0.8711 (0.000)

# %%
clients_ = {}
data_imp = ret9['data']['imputed_data']
missing_mask = ret9['data']['missing_mask']
data_true = ret9['data']['origin_data']
n_clients = ret9['data']['origin_data'].shape[0]
test_data = ret9['data']['test_data']
for client_id in range(n_clients):
    clients_[client_id] = SimpleClient(
        client_id=client_id,
        data_imp=data_imp[client_id],
        missing_mask=missing_mask[client_id],
        data_true=data_true[client_id],
        data_test=test_data
    )

pred_config = server_config_tmpl.copy()
server_name = 'fedavg_mlp_pytorch_pred'
server_pred_config = pred_config['server_pred_config']
server_pred_config['train_params']['pred_round'] = 1000
server_config = pred_config['server_config']
server_ = load_server(
        server_name, clients=clients_, server_config=server_config, pred_config=server_pred_config,
        test_data=test_data
    )

pred_ret2 = server_.prediction()
# Out:
# 2023-07-19 08:45:22.275 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 50, test_accu: 0.7733, test_f1: 0.7713, val_loss: 0.5815, val_accu: 0.7029, val_f1: 0.7029
# 2023-07-19 08:46:02.047 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 100, test_accu: 0.8008, test_f1: 0.7994, val_loss: 0.5362, val_accu: 0.7106, val_f1: 0.7104
# 2023-07-19 08:46:40.222 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 150, test_accu: 0.8182, test_f1: 0.8175, val_loss: 0.5268, val_accu: 0.7212, val_f1: 0.7211
# 2023-07-19 08:47:19.003 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 200, test_accu: 0.8268, test_f1: 0.8264, val_loss: 0.5236, val_accu: 0.7298, val_f1: 0.7298
# 2023-07-19 08:47:58.036 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 250, test_accu: 0.8299, test_f1: 0.8296, val_loss: 0.5220, val_accu: 0.7365, val_f1: 0.7365
# 2023-07-19 08:48:38.821 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 300, test_accu: 0.8321, test_f1: 0.8319, val_loss: 0.5209, val_accu: 0.7385, val_f1: 0.7385
# 2023-07-19 08:49:19.300 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 350, test_accu: 0.8326, test_f1: 0.8324, val_loss: 0.5197, val_accu: 0.7404, val_f1: 0.7404
# 2023-07-19 08:49:57.345 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 400, test_accu: 0.8356, test_f1: 0.8354, val_loss: 0.5197, val_accu: 0.7394, val_f1: 0.7394
# 2023-07-19 08:50:35.595 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 450, test_accu: 0.8329, test_f1: 0.8326, val_loss: 0.5194, val_accu: 0.7394, val_f1: 0.7394
# 2023-07-19 08:51:16.262 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 500, test_accu: 0.8339, test_f1: 0.8336, val_loss: 0.5191, val_accu: 0.7413, val_f1: 0.7413
# 2023-07-19 08:51:56.902 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 550, test_accu: 0.8374, test_f1: 0.8372, val_loss: 0.5198, val_accu: 0.7327, val_f1: 0.7326
# 2023-07-19 08:52:36.897 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 600, test_accu: 0.8387, test_f1: 0.8385, val_loss: 0.5198, val_accu: 0.7327, val_f1: 0.7326
# 2023-07-19 08:53:15.354 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 650, test_accu: 0.8406, test_f1: 0.8404, val_loss: 0.5205, val_accu: 0.7327, val_f1: 0.7326
# 2023-07-19 08:53:53.922 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 700, test_accu: 0.8413, test_f1: 0.8411, val_loss: 0.5211, val_accu: 0.7327, val_f1: 0.7325
# 2023-07-19 08:54:33.286 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 750, test_accu: 0.8419, test_f1: 0.8417, val_loss: 0.5202, val_accu: 0.7327, val_f1: 0.7326
# 2023-07-19 08:55:11.835 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 800, test_accu: 0.8432, test_f1: 0.8430, val_loss: 0.5197, val_accu: 0.7317, val_f1: 0.7317
# 2023-07-19 08:55:50.372 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 850, test_accu: 0.8408, test_f1: 0.8406, val_loss: 0.5188, val_accu: 0.7356, val_f1: 0.7356
# 2023-07-19 08:56:28.712 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 900, test_accu: 0.8450, test_f1: 0.8448, val_loss: 0.5195, val_accu: 0.7346, val_f1: 0.7346
# 2023-07-19 08:57:06.967 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 950, test_accu: 0.8425, test_f1: 0.8423, val_loss: 0.5194, val_accu: 0.7375, val_f1: 0.7375
# 2023-07-19 08:57:44.772 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 1000, test_accu: 0.8471, test_f1: 0.8469, val_loss: 0.5200, val_accu: 0.7356, val_f1: 0.7355
# 2023-07-19 08:57:44.773 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:164 - model1 test acc: 0.859108 (0.000), test f1: 0.859030 (0.000)

# %% [markdown]
# ## MNAR RL

# %%
config2 = experiment_config_template.copy()
config2['data']['dataset_name'] = 'statlog'
config2['num_clients'] = 20
config2['missing_simulate']['mr_strategy'] = 'fixed@mr=0.5'
config2['missing_simulate']['mf_strategy'] = 'all'
config2['missing_simulate']['mm_strategy'] = 'mnar_rl@sp=extreme'
config2['data_partition']['strategy'] = 'sample@p=0.01'
config2['agg_strategy_imp']['strategy'] = 'fedavg-s'

configuration = config2
num_clients = configuration['num_clients']
# set random seed
seed = configuration['experiment']['seed']
mtp = configuration['experiment']['mtp']
tune_params = configuration['tune_params']
random.seed(seed)  # seed for split data

# load data
dataset_params = configuration['data']
data, data_config = load_data(**dataset_params)
regression = data_config['task_type'] == 'regression'

n_rounds = configuration['experiment']['n_rounds']
test_size = configuration['experiment'].get('test_size', 0.1)
if n_rounds == 1:
    n_rounds_data = split_train_test(data, n_folds=2, seed=seed, test_size=test_size, regression=regression)
else:
    n_rounds_data = split_train_test(
        data, n_folds=n_rounds, seed=seed, test_size=test_size, regression=regression
        )

# n rounds average
train_data, test_data = n_rounds_data[0]

new_seed = (seed + 10087 * 0) % (2 ^ 23)
regression = data_config['task_type'] == 'regression'
data_partition_params = configuration['data_partition']
data_partitions = data_partition(
    **data_partition_params, data=train_data.values, n_clients=num_clients, seed=new_seed,
    regression=regression
)
missing_params = configuration['missing_simulate']
cols = np.arange(0, train_data.shape[1] - 1)
scenario = missing_params
data_ms_clients2 = add_missing(
    train_data_list=data_partitions, scenario=scenario, cols=cols, seed=new_seed
)

client_factory = ClientsFactory(debug=False)
clients = client_factory.generate_clients(
    num_clients, data_partitions, data_ms_clients2, test_data.values, data_config,
    configuration['imputation'], seed=new_seed
)

visualize_ms(data_ms_clients2)
# Out:
# sample {'p': '0.01'}
# ['mnar_quantile_right' 'mnar_quantile_right' 'mnar_quantile_left'
#  'mnar_quantile_left' 'mnar_quantile_left' 'mnar_quantile_left'
#  'mnar_quantile_left' 'mnar_quantile_left' 'mnar_quantile_left'
#  'mnar_quantile_left' 'mnar_quantile_left' 'mnar_quantile_left'
#  'mnar_quantile_left' 'mnar_quantile_left' 'mnar_quantile_left'
#  'mnar_quantile_left' 'mnar_quantile_left' 'mnar_quantile_left'
#  'mnar_quantile_left' 'mnar_quantile_left']

# %% [markdown]
# ### Simple Averaging

# %%
configuration['agg_strategy_imp']['strategy'] = 'fedavg-s'
configuration['server_type'] = 'fedavg_pytorch'
configuration['prediction'] = False
configuration['save_state'] = True
configuration['track'] = True

# Create Imputation Strategy
imp_strategy = configuration['agg_strategy_imp']['strategy']
params = configuration['algo_params'][imp_strategy]

strategy_imp = StrategyImputation(strategy=imp_strategy, params=params)

# Create Server
server_type = configuration['server_type']
server_config = configuration['server']
server_config["n_cols"] = test_data.shape[1] - 1

pred_config = configuration['pred_model']
pred_config['model_params']['input_feature_dim'] = test_data.shape[1] - 1
pred_config['model_params']['output_classes_dim'] = len(np.unique(test_data.iloc[:, -1].values))

server = load_server(
    server_type,
    clients=clients,
    strategy_imp=strategy_imp,
    server_config=server_config,
    pred_config=pred_config,
    test_data=test_data.values,
    seed=new_seed,
    track=configuration['track'],
    run_prediction=configuration['prediction'],
    persist_data=configuration['save_state'],
)

# return server
ret5 = server.run()
# Out:
# 2023-07-19 12:23:07.895 | INFO     | src.fed_imp.sub_modules.server.base_server:run:155 - FL finished in 39.26537239999743

# %%
x = list(range(len(ret5['client_imp_history'])))
client_ids = list(ret5['client_imp_history'][0][2]['metrics'].keys())

fig, ax = plt.subplots(1, 1, figsize=(10, 5))
for client_id in client_ids:
    y = [ret5['client_imp_history'][i][2]['metrics'][client_id]['imp@rmse'] for i in x]
    ax.plot(x, y, label=client_id)
plt.show()

# %%
sklearn_evaluation(ret5)
# Out:
# Accuracy imputed centralized MLP:0.8910 (0.017)
# Accuracy imputed centralized LR:0.7634 (0.000)
# Accuracy orignal centralized MLP:0.9895 (0.004)
# Accuracy orignal centralized MLP:0.9659 (0.000)

# %%
clients_ = {}
data_imp = ret5['data']['imputed_data']
missing_mask = ret5['data']['missing_mask']
data_true = ret5['data']['origin_data']
n_client = ret5['data']['origin_data'].shape[0]
test_data = ret5['data']['test_data']
for client_id in range(n_clients):
    clients_[client_id] = SimpleClient(
        client_id=client_id,
        data_imp=data_imp[client_id],
        missing_mask=missing_mask[client_id],
        data_true=data_true[client_id],
        data_test=test_data
    )

pred_config = server_config_tmpl.copy()
server_name = 'fedavg_mlp_pytorch_pred'
server_pred_config = pred_config['server_pred_config']
server_pred_config['train_params']['pred_round'] = 1000
server_config = pred_config['server_config']
server_ = load_server(
        server_name, clients=clients_, server_config=server_config, pred_config=server_pred_config,
        test_data=test_data
    )

pred_ret5 = server_.prediction()
# Out:
# 2023-07-19 09:42:30.559 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 50, test_accu: 0.6611, test_f1: 0.6589, val_loss: 0.6815, val_accu: 0.6000, val_f1: 0.5966
# 2023-07-19 09:43:09.122 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 100, test_accu: 0.7392, test_f1: 0.7336, val_loss: 0.6450, val_accu: 0.6433, val_f1: 0.6403
# 2023-07-19 09:43:47.742 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 150, test_accu: 0.7366, test_f1: 0.7296, val_loss: 0.6323, val_accu: 0.6452, val_f1: 0.6413
# 2023-07-19 09:44:25.684 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 200, test_accu: 0.7431, test_f1: 0.7367, val_loss: 0.6263, val_accu: 0.6548, val_f1: 0.6535
# 2023-07-19 09:45:04.481 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 250, test_accu: 0.7385, test_f1: 0.7327, val_loss: 0.6237, val_accu: 0.6587, val_f1: 0.6575
# 2023-07-19 09:45:46.243 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 300, test_accu: 0.7391, test_f1: 0.7340, val_loss: 0.6221, val_accu: 0.6577, val_f1: 0.6570
# 2023-07-19 09:46:26.861 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 350, test_accu: 0.7461, test_f1: 0.7416, val_loss: 0.6205, val_accu: 0.6596, val_f1: 0.6594
# 2023-07-19 09:47:05.265 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 400, test_accu: 0.7588, test_f1: 0.7554, val_loss: 0.6210, val_accu: 0.6577, val_f1: 0.6575
# 2023-07-19 09:47:42.463 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 450, test_accu: 0.7614, test_f1: 0.7582, val_loss: 0.6196, val_accu: 0.6567, val_f1: 0.6567
# 2023-07-19 09:48:22.075 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 500, test_accu: 0.7640, test_f1: 0.7614, val_loss: 0.6194, val_accu: 0.6567, val_f1: 0.6567
# 2023-07-19 09:48:59.016 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 550, test_accu: 0.7631, test_f1: 0.7600, val_loss: 0.6186, val_accu: 0.6442, val_f1: 0.6434
# 2023-07-19 09:49:36.699 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 600, test_accu: 0.7607, test_f1: 0.7598, val_loss: 0.6239, val_accu: 0.6606, val_f1: 0.6540
# 2023-07-19 09:50:15.446 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 650, test_accu: 0.7573, test_f1: 0.7567, val_loss: 0.6239, val_accu: 0.6538, val_f1: 0.6465
# 2023-07-19 09:50:36.461 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:154 - Early stop at round 677
# 2023-07-19 09:50:36.462 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:164 - model1 test acc: 0.779206 (0.000), test f1: 0.778954 (0.000)

# %% [markdown]
# ### Complementary Models without exchanging initialization

# %%
config2 = experiment_config_template.copy()
config2['data']['dataset_name'] = 'statlog'
config2['num_clients'] = 20
config2['missing_simulate']['mr_strategy'] = 'fixed@mr=0.5'
config2['missing_simulate']['mf_strategy'] = 'all'
config2['missing_simulate']['mm_strategy'] = 'mnar_rl@sp=extreme'
config2['data_partition']['strategy'] = 'sample@p=0.01'
config2['agg_strategy_imp']['strategy'] = 'testavg2'

configuration = config2
num_clients = configuration['num_clients']
# set random seed
seed = configuration['experiment']['seed']
mtp = configuration['experiment']['mtp']
tune_params = configuration['tune_params']
random.seed(seed)  # seed for split data

# load data
dataset_params = configuration['data']
data, data_config = load_data(**dataset_params)
regression = data_config['task_type'] == 'regression'

n_rounds = configuration['experiment']['n_rounds']
test_size = configuration['experiment'].get('test_size', 0.1)
if n_rounds == 1:
    n_rounds_data = split_train_test(data, n_folds=2, seed=seed, test_size=test_size, regression=regression)
else:
    n_rounds_data = split_train_test(
        data, n_folds=n_rounds, seed=seed, test_size=test_size, regression=regression
        )

# n rounds average
train_data, test_data = n_rounds_data[0]

new_seed = (seed + 10087 * 0) % (2 ^ 23)
regression = data_config['task_type'] == 'regression'
data_partition_params = configuration['data_partition']
data_partitions = data_partition(
    **data_partition_params, data=train_data.values, n_clients=num_clients, seed=new_seed,
    regression=regression
)
missing_params = configuration['missing_simulate']
cols = np.arange(0, train_data.shape[1] - 1)
scenario = missing_params
data_ms_clients2 = add_missing(
    train_data_list=data_partitions, scenario=scenario, cols=cols, seed=new_seed
)

client_factory = ClientsFactory(debug=False)
clients = client_factory.generate_clients(
    num_clients, data_partitions, data_ms_clients2, test_data.values, data_config,
    configuration['imputation'], seed=new_seed
)
# Out:
# sample {'p': '0.01'}
# ['mnar_quantile_right' 'mnar_quantile_right' 'mnar_quantile_left'
#  'mnar_quantile_left' 'mnar_quantile_left' 'mnar_quantile_left'
#  'mnar_quantile_left' 'mnar_quantile_left' 'mnar_quantile_left'
#  'mnar_quantile_left' 'mnar_quantile_left' 'mnar_quantile_left'
#  'mnar_quantile_left' 'mnar_quantile_left' 'mnar_quantile_left'
#  'mnar_quantile_left' 'mnar_quantile_left' 'mnar_quantile_left'
#  'mnar_quantile_left' 'mnar_quantile_left']

# %%
configuration['agg_strategy_imp']['strategy'] = 'testavg2'
configuration['server_type'] = 'fedavg_pytorch'
configuration['prediction'] = False
configuration['save_state'] = True
configuration['track'] = True

# Create Imputation Strategy
imp_strategy = configuration['agg_strategy_imp']['strategy']
params = configuration['algo_params'][imp_strategy]

strategy_imp = StrategyImputation(strategy=imp_strategy, params=params)

# Create Server
server_type = configuration['server_type']
server_config = configuration['server']
server_config["n_cols"] = test_data.shape[1] - 1

pred_config = configuration['pred_model']
pred_config['model_params']['input_feature_dim'] = test_data.shape[1] - 1
pred_config['model_params']['output_classes_dim'] = len(np.unique(test_data.iloc[:, -1].values))

server = load_server(
    server_type,
    clients=clients,
    strategy_imp=strategy_imp,
    server_config=server_config,
    pred_config=pred_config,
    test_data=test_data.values,
    seed=new_seed,
    track=configuration['track'],
    run_prediction=configuration['prediction'],
    persist_data=configuration['save_state'],
)

# return server
ret6 = server.run()
# Out:
# testavg2
# 2023-07-19 12:24:01.005 | INFO     | src.fed_imp.sub_modules.server.base_server:run:155 - FL finished in 39.11097370000789

# %%
original_data6 = ret6['data']['origin_data'].reshape(-1, ret6['data']['origin_data'].shape[-1])
print(original_data6.shape)
centralized_data6 = ret6['data']['imputed_data'].reshape(-1, ret6['data']['imputed_data'].shape[-1])
print(centralized_data6.shape)
test_data6 = ret6['data']['test_data']
print(test_data6.shape)
print(ret6['imp_result'])

x = list(range(len(ret6['client_imp_history'])))
client_ids = list(ret6['client_imp_history'][0][2]['metrics'].keys())

fig, ax = plt.subplots(1, 1, figsize=(10, 5))
for client_id in client_ids:
    y = [ret6['client_imp_history'][i][2]['metrics'][client_id]['imp@rmse'] for i in x]
    ax.plot(x, y, label=client_id)
plt.show()
# Out:
# (3420, 10)
# (3420, 10)
# (7302, 10)
# {'imp@rmse': 0.028018786897844095, 'imp@ws': 0.05876847314234421, 'imp@sliced_ws': 0.013436824316977252}

# %%
sklearn_evaluation(ret6)
# Out:
# Accuracy imputed centralized MLP:0.8684 (0.022)
# Accuracy imputed centralized LR:0.8697 (0.000)
# Accuracy orignal centralized MLP:0.9335 (0.003)
# Accuracy orignal centralized MLP:0.8711 (0.000)

# %%
clients_ = {}
data_imp = ret6['data']['imputed_data']
missing_mask = ret6['data']['missing_mask']
data_true = ret6['data']['origin_data']
n_clients = ret6['data']['origin_data'].shape[0]
test_data = ret6['data']['test_data']
for client_id in range(n_clients):
    clients_[client_id] = SimpleClient(
        client_id=client_id,
        data_imp=data_imp[client_id],
        missing_mask=missing_mask[client_id],
        data_true=data_true[client_id],
        data_test=test_data
    )

pred_config = server_config_tmpl.copy()
server_name = 'fedavg_mlp_pytorch_pred'
server_pred_config = pred_config['server_pred_config']
server_pred_config['train_params']['pred_round'] = 1000
server_config = pred_config['server_config']
server_ = load_server(
        server_name, clients=clients_, server_config=server_config, pred_config=server_pred_config,
        test_data=test_data
    )

pred_ret6 = server_.prediction()
# Out:
# 2023-07-19 06:46:04.438 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 50, test_accu: 0.7985, test_f1: 0.7975, val_loss: 0.5299, val_accu: 0.7490, val_f1: 0.7455
# 2023-07-19 06:46:45.293 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 100, test_accu: 0.8440, test_f1: 0.8439, val_loss: 0.4700, val_accu: 0.7808, val_f1: 0.7790
# 2023-07-19 06:47:29.234 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 150, test_accu: 0.8500, test_f1: 0.8500, val_loss: 0.4531, val_accu: 0.7962, val_f1: 0.7950
# 2023-07-19 06:48:11.901 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 200, test_accu: 0.8526, test_f1: 0.8526, val_loss: 0.4443, val_accu: 0.8048, val_f1: 0.8042
# 2023-07-19 06:48:54.407 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 250, test_accu: 0.8549, test_f1: 0.8549, val_loss: 0.4387, val_accu: 0.8115, val_f1: 0.8113
# 2023-07-19 06:49:36.465 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 300, test_accu: 0.8597, test_f1: 0.8597, val_loss: 0.4349, val_accu: 0.8202, val_f1: 0.8201
# 2023-07-19 06:50:19.100 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 350, test_accu: 0.8609, test_f1: 0.8609, val_loss: 0.4320, val_accu: 0.8202, val_f1: 0.8201
# 2023-07-19 06:51:00.866 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 400, test_accu: 0.8613, test_f1: 0.8613, val_loss: 0.4300, val_accu: 0.8202, val_f1: 0.8202
# 2023-07-19 06:51:42.076 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 450, test_accu: 0.8625, test_f1: 0.8624, val_loss: 0.4274, val_accu: 0.8240, val_f1: 0.8240
# 2023-07-19 06:52:22.526 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 500, test_accu: 0.8660, test_f1: 0.8660, val_loss: 0.4248, val_accu: 0.8279, val_f1: 0.8279
# 2023-07-19 06:53:01.482 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 550, test_accu: 0.8635, test_f1: 0.8634, val_loss: 0.4229, val_accu: 0.8260, val_f1: 0.8260
# 2023-07-19 06:53:39.169 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 600, test_accu: 0.8638, test_f1: 0.8638, val_loss: 0.4206, val_accu: 0.8269, val_f1: 0.8269
# 2023-07-19 06:54:18.002 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 650, test_accu: 0.8666, test_f1: 0.8666, val_loss: 0.4179, val_accu: 0.8308, val_f1: 0.8308
# 2023-07-19 06:55:00.504 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 700, test_accu: 0.8668, test_f1: 0.8667, val_loss: 0.4140, val_accu: 0.8327, val_f1: 0.8327
# 2023-07-19 06:55:44.004 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 750, test_accu: 0.8684, test_f1: 0.8683, val_loss: 0.4099, val_accu: 0.8337, val_f1: 0.8336
# 2023-07-19 06:56:27.268 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 800, test_accu: 0.8685, test_f1: 0.8684, val_loss: 0.4044, val_accu: 0.8327, val_f1: 0.8327
# 2023-07-19 06:57:10.963 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 850, test_accu: 0.8694, test_f1: 0.8693, val_loss: 0.4007, val_accu: 0.8317, val_f1: 0.8317
# 2023-07-19 06:57:53.239 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 900, test_accu: 0.8710, test_f1: 0.8708, val_loss: 0.3964, val_accu: 0.8288, val_f1: 0.8288
# 2023-07-19 06:58:32.773 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 950, test_accu: 0.8721, test_f1: 0.8720, val_loss: 0.3924, val_accu: 0.8308, val_f1: 0.8308
# 2023-07-19 06:59:11.165 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 1000, test_accu: 0.8724, test_f1: 0.8723, val_loss: 0.3892, val_accu: 0.8346, val_f1: 0.8346
# 2023-07-19 06:59:11.167 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:164 - model1 test acc: 0.881006 (0.000), test f1: 0.881006 (0.000)

# %% [markdown]
# ### Our Method

# %%
config2 = experiment_config_template.copy()
config2['data']['dataset_name'] = 'statlog'
config2['num_clients'] = 20
config2['missing_simulate']['mr_strategy'] = 'fixed@mr=0.5'
config2['missing_simulate']['mf_strategy'] = 'all'
config2['missing_simulate']['mm_strategy'] = 'mnar_rl@sp=extreme'
config2['data_partition']['strategy'] = 'sample@p=0.01'
config2['agg_strategy_imp']['strategy'] = 'fedmechw'

configuration = config2
num_clients = configuration['num_clients']
# set random seed
seed = configuration['experiment']['seed']
mtp = configuration['experiment']['mtp']
tune_params = configuration['tune_params']
random.seed(seed)  # seed for split data

# load data
dataset_params = configuration['data']
data, data_config = load_data(**dataset_params)
regression = data_config['task_type'] == 'regression'

n_rounds = configuration['experiment']['n_rounds']
test_size = configuration['experiment'].get('test_size', 0.1)
if n_rounds == 1:
    n_rounds_data = split_train_test(data, n_folds=2, seed=seed, test_size=test_size, regression=regression)
else:
    n_rounds_data = split_train_test(
        data, n_folds=n_rounds, seed=seed, test_size=test_size, regression=regression
        )

# n rounds average
train_data, test_data = n_rounds_data[0]

new_seed = (seed + 10087 * 0) % (2 ^ 23)
regression = data_config['task_type'] == 'regression'
data_partition_params = configuration['data_partition']
data_partitions = data_partition(
    **data_partition_params, data=train_data.values, n_clients=num_clients, seed=new_seed,
    regression=regression
)
missing_params = configuration['missing_simulate']
cols = np.arange(0, train_data.shape[1] - 1)
scenario = missing_params
data_ms_clients2 = add_missing(
    train_data_list=data_partitions, scenario=scenario, cols=cols, seed=new_seed
)

client_factory = ClientsFactory(debug=False)
clients = client_factory.generate_clients(
    num_clients, data_partitions, data_ms_clients2, test_data.values, data_config,
    configuration['imputation'], seed=new_seed
)
# Out:
# sample {'p': '0.01'}
# ['mnar_quantile_right' 'mnar_quantile_right' 'mnar_quantile_left'
#  'mnar_quantile_left' 'mnar_quantile_left' 'mnar_quantile_left'
#  'mnar_quantile_left' 'mnar_quantile_left' 'mnar_quantile_left'
#  'mnar_quantile_left' 'mnar_quantile_left' 'mnar_quantile_left'
#  'mnar_quantile_left' 'mnar_quantile_left' 'mnar_quantile_left'
#  'mnar_quantile_left' 'mnar_quantile_left' 'mnar_quantile_left'
#  'mnar_quantile_left' 'mnar_quantile_left']

# %%
configuration['agg_strategy_imp']['strategy'] = 'fedmechw'
configuration['server_type'] = 'fedavg_pytorch'
configuration['prediction'] = False
configuration['save_state'] = True
configuration['track'] = True
configuration['algo_params']["fedmechw"] = {
    "client_thres": 0.4,
    "alpha": 1.0,
    "beta": 0
}

# Create Imputation Strategy
imp_strategy = configuration['agg_strategy_imp']['strategy']
params = configuration['algo_params'][imp_strategy]

strategy_imp = StrategyImputation(strategy=imp_strategy, params=params)

# Create Server
server_type = configuration['server_type']
server_config = configuration['server']
server_config["n_cols"] = test_data.shape[1] - 1

pred_config = configuration['pred_model']
pred_config['model_params']['input_feature_dim'] = test_data.shape[1] - 1
pred_config['model_params']['output_classes_dim'] = len(np.unique(test_data.iloc[:, -1].values))

server = load_server(
    server_type,
    clients=clients,
    strategy_imp=strategy_imp,
    server_config=server_config,
    pred_config=pred_config,
    test_data=test_data.values,
    seed=new_seed,
    track=configuration['track'],
    run_prediction=configuration['prediction'],
    persist_data=configuration['save_state'],
)

# return server
ret10 = server.run()
# Out:
# 2023-07-19 12:25:22.065 | INFO     | src.fed_imp.sub_modules.server.base_server:run:155 - FL finished in 40.03559260000475

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
for client_id in client_ids:
    y = [ret10['client_imp_history'][i][2]['metrics'][client_id]['imp@rmse'] for i in x]
    ax.plot(x, y, label=client_id)
plt.show()

ret10['imp_result']
# Out:
# {'imp@rmse': 0.02643861895796254,
#  'imp@ws': 0.05357680201656758,
#  'imp@sliced_ws': 0.012445045221592796}

# %%
sklearn_evaluation(ret10)
# Out:
# Accuracy imputed centralized MLP:0.9739 (0.003)
# Accuracy imputed centralized LR:0.9634 (0.000)
# Accuracy orignal centralized MLP:0.9895 (0.004)
# Accuracy orignal centralized MLP:0.9659 (0.000)

# %%
clients_ = {}
data_imp = ret10['data']['imputed_data']
missing_mask = ret10['data']['missing_mask']
data_true = ret10['data']['origin_data']
n_clients = ret10['data']['origin_data'].shape[0]
test_data = ret10['data']['test_data']
for client_id in range(n_clients):
    clients_[client_id] = SimpleClient(
        client_id=client_id,
        data_imp=data_imp[client_id],
        missing_mask=missing_mask[client_id],
        data_true=data_true[client_id],
        data_test=test_data
    )

pred_config = server_config_tmpl.copy()
server_name = 'fedavg_mlp_pytorch_pred'
server_pred_config = pred_config['server_pred_config']
server_pred_config['train_params']['pred_round'] = 1000
server_config = pred_config['server_config']
server_ = load_server(
        server_name, clients=clients_, server_config=server_config, pred_config=server_pred_config,
        test_data=test_data
    )

pred_ret2 = server_.prediction()
# Out:
# 2023-07-19 09:07:52.502 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 50, test_accu: 0.8014, test_f1: 0.8013, val_loss: 0.5364, val_accu: 0.7423, val_f1: 0.7391
# 2023-07-19 09:08:30.196 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 100, test_accu: 0.8416, test_f1: 0.8416, val_loss: 0.4812, val_accu: 0.7702, val_f1: 0.7684
# 2023-07-19 09:09:08.298 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 150, test_accu: 0.8473, test_f1: 0.8472, val_loss: 0.4659, val_accu: 0.7779, val_f1: 0.7764
# 2023-07-19 09:09:47.071 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 200, test_accu: 0.8489, test_f1: 0.8488, val_loss: 0.4586, val_accu: 0.7846, val_f1: 0.7836
# 2023-07-19 09:10:24.968 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 250, test_accu: 0.8478, test_f1: 0.8477, val_loss: 0.4528, val_accu: 0.7894, val_f1: 0.7887
# 2023-07-19 09:11:02.308 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 300, test_accu: 0.8519, test_f1: 0.8518, val_loss: 0.4485, val_accu: 0.7923, val_f1: 0.7917
# 2023-07-19 09:11:40.390 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 350, test_accu: 0.8549, test_f1: 0.8547, val_loss: 0.4455, val_accu: 0.7981, val_f1: 0.7978
# 2023-07-19 09:12:18.050 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 400, test_accu: 0.8568, test_f1: 0.8567, val_loss: 0.4430, val_accu: 0.8000, val_f1: 0.7997
# 2023-07-19 09:12:56.187 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 450, test_accu: 0.8581, test_f1: 0.8580, val_loss: 0.4403, val_accu: 0.8038, val_f1: 0.8037
# 2023-07-19 09:13:36.087 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 500, test_accu: 0.8590, test_f1: 0.8590, val_loss: 0.4379, val_accu: 0.7981, val_f1: 0.7980
# 2023-07-19 09:14:15.479 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 550, test_accu: 0.8622, test_f1: 0.8621, val_loss: 0.4340, val_accu: 0.8144, val_f1: 0.8144
# 2023-07-19 09:14:54.720 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 600, test_accu: 0.8627, test_f1: 0.8625, val_loss: 0.4339, val_accu: 0.8115, val_f1: 0.8112
# 2023-07-19 09:15:35.219 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 650, test_accu: 0.8652, test_f1: 0.8651, val_loss: 0.4278, val_accu: 0.8183, val_f1: 0.8181
# 2023-07-19 09:16:15.188 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 700, test_accu: 0.8670, test_f1: 0.8669, val_loss: 0.4248, val_accu: 0.8240, val_f1: 0.8239
# 2023-07-19 09:16:53.966 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 750, test_accu: 0.8684, test_f1: 0.8684, val_loss: 0.4216, val_accu: 0.8212, val_f1: 0.8210
# 2023-07-19 09:17:32.536 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 800, test_accu: 0.8701, test_f1: 0.8700, val_loss: 0.4185, val_accu: 0.8260, val_f1: 0.8257
# 2023-07-19 09:18:11.245 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 850, test_accu: 0.8729, test_f1: 0.8729, val_loss: 0.4130, val_accu: 0.8288, val_f1: 0.8288
# 2023-07-19 09:18:50.029 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 900, test_accu: 0.8744, test_f1: 0.8744, val_loss: 0.4112, val_accu: 0.8327, val_f1: 0.8326
# 2023-07-19 09:19:28.640 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 950, test_accu: 0.8755, test_f1: 0.8755, val_loss: 0.4076, val_accu: 0.8346, val_f1: 0.8345
# 2023-07-19 09:20:07.085 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 1000, test_accu: 0.8772, test_f1: 0.8772, val_loss: 0.4041, val_accu: 0.8365, val_f1: 0.8364
# 2023-07-19 09:20:07.087 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:164 - model1 test acc: 0.878201 (0.000), test f1: 0.878182 (0.000)

# %% [markdown]
# ## MARY Sigmoid - more patterns

# %%
config = experiment_config_template.copy()
config['data']['dataset_name'] = 'statlog'
config['num_clients'] = 20
config['missing_simulate']['mr_strategy'] = 'fixed@mr=0.5'
config['missing_simulate']['mf_strategy'] = 'all'
config['missing_simulate']['mm_strategy'] = 'mary_sigmoid_lr@sp=extreme'
config['data_partition']['strategy'] = 'sample@p=0.01'

configuration = config
num_clients = configuration['num_clients']
# set random seed
seed = configuration['experiment']['seed']
mtp = configuration['experiment']['mtp']
tune_params = configuration['tune_params']
random.seed(seed)  # seed for split data

# load data
dataset_params = configuration['data']
data, data_config = load_data(**dataset_params)
regression = data_config['task_type'] == 'regression'

n_rounds = configuration['experiment']['n_rounds']
test_size = configuration['experiment'].get('test_size', 0.1)
if n_rounds == 1:
    n_rounds_data = split_train_test(data, n_folds=2, seed=seed, test_size=test_size, regression=regression)
else:
    n_rounds_data = split_train_test(
        data, n_folds=n_rounds, seed=seed, test_size=test_size, regression=regression
        )

# n rounds average
train_data, test_data = n_rounds_data[0]

new_seed = (seed + 10087 * 0) % (2 ^ 23)
regression = data_config['task_type'] == 'regression'
data_partition_params = configuration['data_partition']
data_partitions = data_partition(
    **data_partition_params, data=train_data.values, n_clients=num_clients, seed=new_seed,
    regression=regression
)
missing_params = configuration['missing_simulate']
cols = np.arange(0, train_data.shape[1] - 1)
scenario = missing_params
data_ms_clients = add_missing(
    train_data_list=data_partitions, scenario=scenario, cols=cols, seed=new_seed
)

client_factory = ClientsFactory(debug=False)
clients = client_factory.generate_clients(
    num_clients, data_partitions, data_ms_clients, test_data.values, data_config,
    configuration['imputation'], seed=new_seed
)
visualize_ms(data_ms_clients)
# Out:
# sample {'p': '0.01'}
# ['mary_sigmoid_left' 'mary_sigmoid_left' 'mary_sigmoid_right'
#  'mary_sigmoid_right' 'mary_sigmoid_right' 'mary_sigmoid_right'
#  'mary_sigmoid_right' 'mary_sigmoid_right' 'mary_sigmoid_right'
#  'mary_sigmoid_right' 'mary_sigmoid_right' 'mary_sigmoid_right'
#  'mary_sigmoid_right' 'mary_sigmoid_right' 'mary_sigmoid_right'
#  'mary_sigmoid_right' 'mary_sigmoid_right' 'mary_sigmoid_right'
#  'mary_sigmoid_right' 'mary_sigmoid_right']

# %% [markdown]
# ### Simple Averaging

# %%
configuration['agg_strategy_imp']['strategy'] = 'fedavg-s'
configuration['server_type'] = 'fedavg_pytorch'
configuration['prediction'] = False
configuration['save_state'] = True
configuration['track'] = True

# Create Imputation Strategy
imp_strategy = configuration['agg_strategy_imp']['strategy']
params = configuration['algo_params'][imp_strategy]

strategy_imp = StrategyImputation(strategy=imp_strategy, params=params)

# Create Server
server_type = configuration['server_type']
server_config = configuration['server']
server_config["n_cols"] = test_data.shape[1] - 1

pred_config = configuration['pred_model']
pred_config['model_params']['input_feature_dim'] = test_data.shape[1] - 1
pred_config['model_params']['output_classes_dim'] = len(np.unique(test_data.iloc[:, -1].values))

server = load_server(
    server_type,
    clients=clients,
    strategy_imp=strategy_imp,
    server_config=server_config,
    pred_config=pred_config,
    test_data=test_data.values,
    seed=new_seed,
    track=configuration['track'],
    run_prediction=configuration['prediction'],
    persist_data=configuration['save_state'],
)

# return server
ret7 = server.run()
# Out:
# 2023-07-19 12:29:28.098 | INFO     | src.fed_imp.sub_modules.server.base_server:run:155 - FL finished in 40.40556020004442

# %%
x = list(range(len(ret7['client_imp_history'])))
client_ids = list(ret7['client_imp_history'][0][2]['metrics'].keys())

fig, ax = plt.subplots(1, 1, figsize=(10, 5))
for client_id in client_ids:
    y = [ret7['client_imp_history'][i][2]['metrics'][client_id]['imp@rmse'] for i in x]
    ax.plot(x, y, label=client_id)
plt.show()
print(ret7['imp_result'])
# Out:
# {'imp@rmse': 0.05891510038649005, 'imp@ws': 0.10644542372904495, 'imp@sliced_ws': 0.02286132185369778}

# %%
sklearn_evaluation(ret7)
# Out:
# Accuracy imputed centralized MLP:0.9712 (0.006)
# Accuracy imputed centralized LR:0.8637 (0.000)
# Accuracy orignal centralized MLP:0.9895 (0.004)
# Accuracy orignal centralized MLP:0.9659 (0.000)

# %%
clients_ = {}
data_imp = ret7['data']['imputed_data']
missing_mask = ret7['data']['missing_mask']
data_true = ret7['data']['origin_data']
n_client = ret7['data']['origin_data'].shape[0]
test_data = ret7['data']['test_data']
for client_id in range(n_clients):
    clients_[client_id] = SimpleClient(
        client_id=client_id,
        data_imp=data_imp[client_id],
        missing_mask=missing_mask[client_id],
        data_true=data_true[client_id],
        data_test=test_data
    )

pred_config = server_config_tmpl.copy()
server_name = 'fedavg_mlp_pytorch_pred'
server_pred_config = pred_config['server_pred_config']
server_pred_config['train_params']['pred_round'] = 500
server_config = pred_config['server_config']
server_ = load_server(
        server_name, clients=clients_, server_config=server_config, pred_config=server_pred_config,
        test_data=test_data
    )

pred_ret7 = server_.prediction()
# Out:
# 2023-07-19 09:56:33.065 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 50, test_accu: 0.5714, test_f1: 0.4807, val_loss: 0.4668, val_accu: 0.7817, val_f1: 0.7816
# 2023-07-19 09:57:14.495 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 100, test_accu: 0.6018, test_f1: 0.5319, val_loss: 0.4195, val_accu: 0.8058, val_f1: 0.8055
# 2023-07-19 09:57:53.584 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 150, test_accu: 0.6040, test_f1: 0.5361, val_loss: 0.4103, val_accu: 0.8183, val_f1: 0.8180
# 2023-07-19 09:58:33.374 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 200, test_accu: 0.6021, test_f1: 0.5331, val_loss: 0.4067, val_accu: 0.8308, val_f1: 0.8305
# 2023-07-19 09:59:12.744 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 250, test_accu: 0.5963, test_f1: 0.5227, val_loss: 0.3974, val_accu: 0.8356, val_f1: 0.8354
# 2023-07-19 09:59:52.275 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 300, test_accu: 0.5958, test_f1: 0.5213, val_loss: 0.3927, val_accu: 0.8375, val_f1: 0.8373
# 2023-07-19 10:00:30.770 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 350, test_accu: 0.5892, test_f1: 0.5100, val_loss: 0.3894, val_accu: 0.8385, val_f1: 0.8382
# 2023-07-19 10:01:13.748 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 400, test_accu: 0.5855, test_f1: 0.5032, val_loss: 0.3898, val_accu: 0.8375, val_f1: 0.8372
# 2023-07-19 10:01:52.967 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 450, test_accu: 0.5814, test_f1: 0.4951, val_loss: 0.3879, val_accu: 0.8394, val_f1: 0.8392
# 2023-07-19 10:01:53.818 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:154 - Early stop at round 451
# 2023-07-19 10:01:53.820 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:164 - model1 test acc: 0.609176 (0.000), test f1: 0.547500 (0.000)

# %% [markdown]
# ### Complementary models

# %%
config = experiment_config_template.copy()
config['data']['dataset_name'] = 'statlog'
config['num_clients'] = 20
config['missing_simulate']['mr_strategy'] = 'fixed@mr=0.5'
config['missing_simulate']['mf_strategy'] = 'all'
config['missing_simulate']['mm_strategy'] = 'mary_sigmoid_lr@sp=extreme'
config['data_partition']['strategy'] = 'sample@p=0.01'

configuration = config
num_clients = configuration['num_clients']
# set random seed
seed = configuration['experiment']['seed']
mtp = configuration['experiment']['mtp']
tune_params = configuration['tune_params']
random.seed(seed)  # seed for split data

# load data
dataset_params = configuration['data']
data, data_config = load_data(**dataset_params)
regression = data_config['task_type'] == 'regression'

n_rounds = configuration['experiment']['n_rounds']
test_size = configuration['experiment'].get('test_size', 0.1)
if n_rounds == 1:
    n_rounds_data = split_train_test(data, n_folds=2, seed=seed, test_size=test_size, regression=regression)
else:
    n_rounds_data = split_train_test(
        data, n_folds=n_rounds, seed=seed, test_size=test_size, regression=regression
        )

# n rounds average
train_data, test_data = n_rounds_data[0]

new_seed = (seed + 10087 * 0) % (2 ^ 23)
regression = data_config['task_type'] == 'regression'
data_partition_params = configuration['data_partition']
data_partitions = data_partition(
    **data_partition_params, data=train_data.values, n_clients=num_clients, seed=new_seed,
    regression=regression
)
missing_params = configuration['missing_simulate']
cols = np.arange(0, train_data.shape[1] - 1)
scenario = missing_params
data_ms_clients = add_missing(
    train_data_list=data_partitions, scenario=scenario, cols=cols, seed=new_seed
)

client_factory = ClientsFactory(debug=False)
clients = client_factory.generate_clients(
    num_clients, data_partitions, data_ms_clients, test_data.values, data_config,
    configuration['imputation'], seed=new_seed
)
visualize_ms(data_ms_clients)
# Out:
# sample {'p': '0.01'}
# ['mary_sigmoid_left' 'mary_sigmoid_left' 'mary_sigmoid_right'
#  'mary_sigmoid_right' 'mary_sigmoid_right' 'mary_sigmoid_right'
#  'mary_sigmoid_right' 'mary_sigmoid_right' 'mary_sigmoid_right'
#  'mary_sigmoid_right' 'mary_sigmoid_right' 'mary_sigmoid_right'
#  'mary_sigmoid_right' 'mary_sigmoid_right' 'mary_sigmoid_right'
#  'mary_sigmoid_right' 'mary_sigmoid_right' 'mary_sigmoid_right'
#  'mary_sigmoid_right' 'mary_sigmoid_right']

# %%
configuration['agg_strategy_imp']['strategy'] = 'testavg2'
configuration['server_type'] = 'fedavg_pytorch'
configuration['prediction'] = False
configuration['save_state'] = True
configuration['track'] = True

# Create Imputation Strategy
imp_strategy = configuration['agg_strategy_imp']['strategy']
params = configuration['algo_params'][imp_strategy]

strategy_imp = StrategyImputation(strategy=imp_strategy, params=params)

# Create Server
server_type = configuration['server_type']
server_config = configuration['server']
server_config["n_cols"] = test_data.shape[1] - 1

pred_config = configuration['pred_model']
pred_config['model_params']['input_feature_dim'] = test_data.shape[1] - 1
pred_config['model_params']['output_classes_dim'] = len(np.unique(test_data.iloc[:, -1].values))

server = load_server(
    server_type,
    clients=clients,
    strategy_imp=strategy_imp,
    server_config=server_config,
    pred_config=pred_config,
    test_data=test_data.values,
    seed=new_seed,
    track=configuration['track'],
    run_prediction=configuration['prediction'],
    persist_data=configuration['save_state'],
)

# return server
ret8 = server.run()
# Out:
# testavg2
# 2023-07-19 12:31:30.071 | INFO     | src.fed_imp.sub_modules.server.base_server:run:155 - FL finished in 39.477760199981276

# %%
print(ret8['imp_result'])

x = list(range(len(ret8['client_imp_history'])))
client_ids = list(ret8['client_imp_history'][0][2]['metrics'].keys())

fig, ax = plt.subplots(1, 1, figsize=(10, 5))
for client_id in client_ids:
    y = [ret8['client_imp_history'][i][2]['metrics'][client_id]['imp@rmse'] for i in x]
    ax.plot(x, y, label=client_id)
plt.show()
# Out:
# {'imp@rmse': 0.0558438018481578, 'imp@ws': 0.096530112676212, 'imp@sliced_ws': 0.021172575672269756}

# %%
sklearn_evaluation(ret8)
# Out:
# Accuracy imputed centralized MLP:0.6273 (0.015)
# Accuracy imputed centralized LR:0.8340 (0.000)
# Accuracy orignal centralized MLP:0.9335 (0.003)
# Accuracy orignal centralized MLP:0.8711 (0.000)

# %%
clients_ = {}
data_imp = ret8['data']['imputed_data']
missing_mask = ret8['data']['missing_mask']
data_true = ret8['data']['origin_data']
n_client = ret8['data']['origin_data'].shape[0]
test_data = ret8['data']['test_data']
for client_id in range(n_clients):
    clients_[client_id] = SimpleClient(
        client_id=client_id,
        data_imp=data_imp[client_id],
        missing_mask=missing_mask[client_id],
        data_true=data_true[client_id],
        data_test=test_data
    )

pred_config = server_config_tmpl.copy()
server_name = 'fedavg_mlp_pytorch_pred'
server_pred_config = pred_config['server_pred_config']
server_pred_config['train_params']['pred_round'] = 500
server_config = pred_config['server_config']
server_ = load_server(
        server_name, clients=clients_, server_config=server_config, pred_config=server_pred_config,
        test_data=test_data
    )

pred_ret8 = server_.prediction()
# Out:
# 2023-07-19 10:08:25.350 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 50, test_accu: 0.5934, test_f1: 0.5212, val_loss: 0.4161, val_accu: 0.8163, val_f1: 0.8163
# 2023-07-19 10:09:01.946 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 100, test_accu: 0.6116, test_f1: 0.5467, val_loss: 0.3697, val_accu: 0.8317, val_f1: 0.8314
# 2023-07-19 10:09:37.857 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 150, test_accu: 0.6151, test_f1: 0.5520, val_loss: 0.3569, val_accu: 0.8394, val_f1: 0.8391
# 2023-07-19 10:10:14.146 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 200, test_accu: 0.6091, test_f1: 0.5416, val_loss: 0.3519, val_accu: 0.8442, val_f1: 0.8438
# 2023-07-19 10:10:53.064 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 250, test_accu: 0.5961, test_f1: 0.5193, val_loss: 0.3442, val_accu: 0.8462, val_f1: 0.8460
# 2023-07-19 10:11:32.593 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 300, test_accu: 0.5916, test_f1: 0.5118, val_loss: 0.3412, val_accu: 0.8529, val_f1: 0.8528
# 2023-07-19 10:12:11.632 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 350, test_accu: 0.5892, test_f1: 0.5076, val_loss: 0.3404, val_accu: 0.8519, val_f1: 0.8518
# 2023-07-19 10:12:50.628 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 400, test_accu: 0.5863, test_f1: 0.5023, val_loss: 0.3389, val_accu: 0.8529, val_f1: 0.8528
# 2023-07-19 10:13:32.386 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 450, test_accu: 0.5835, test_f1: 0.4974, val_loss: 0.3385, val_accu: 0.8548, val_f1: 0.8547
# 2023-07-19 10:13:32.387 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:154 - Early stop at round 450
# 2023-07-19 10:13:32.389 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:164 - model1 test acc: 0.630169 (0.000), test f1: 0.594633 (0.000)

# %% [markdown]
# ### Our Method

# %%
config = experiment_config_template.copy()
config['data']['dataset_name'] = 'ijcnn_balanced_pca'
config['num_clients'] = 20
config['missing_simulate']['mr_strategy'] = 'fixed@mr=0.5'
config['missing_simulate']['mf_strategy'] = 'all'
config['missing_simulate']['mm_strategy'] = 'mary_sigmoid_lr@sp=extreme'
config['data_partition']['strategy'] = 'sample@p=0.01'

configuration = config
num_clients = configuration['num_clients']
# set random seed
seed = configuration['experiment']['seed']
mtp = configuration['experiment']['mtp']
tune_params = configuration['tune_params']
random.seed(seed)  # seed for split data

# load data
dataset_params = configuration['data']
data, data_config = load_data(**dataset_params)
regression = data_config['task_type'] == 'regression'

n_rounds = configuration['experiment']['n_rounds']
test_size = configuration['experiment'].get('test_size', 0.1)
if n_rounds == 1:
    n_rounds_data = split_train_test(data, n_folds=2, seed=seed, test_size=test_size, regression=regression)
else:
    n_rounds_data = split_train_test(
        data, n_folds=n_rounds, seed=seed, test_size=test_size, regression=regression
        )

# n rounds average
train_data, test_data = n_rounds_data[0]

new_seed = (seed + 10087 * 0) % (2 ^ 23)
regression = data_config['task_type'] == 'regression'
data_partition_params = configuration['data_partition']
data_partitions = data_partition(
    **data_partition_params, data=train_data.values, n_clients=num_clients, seed=new_seed,
    regression=regression
)
missing_params = configuration['missing_simulate']
cols = np.arange(0, train_data.shape[1] - 1)
scenario = missing_params
data_ms_clients = add_missing(
    train_data_list=data_partitions, scenario=scenario, cols=cols, seed=new_seed
)

client_factory = ClientsFactory(debug=False)
clients = client_factory.generate_clients(
    num_clients, data_partitions, data_ms_clients, test_data.values, data_config,
    configuration['imputation'], seed=new_seed
)
visualize_ms(data_ms_clients)
# Out:
# sample {'p': '0.01'}
# ['mary_sigmoid_left' 'mary_sigmoid_left' 'mary_sigmoid_right'
#  'mary_sigmoid_right' 'mary_sigmoid_right' 'mary_sigmoid_right'
#  'mary_sigmoid_right' 'mary_sigmoid_right' 'mary_sigmoid_right'
#  'mary_sigmoid_right' 'mary_sigmoid_right' 'mary_sigmoid_right'
#  'mary_sigmoid_right' 'mary_sigmoid_right' 'mary_sigmoid_right'
#  'mary_sigmoid_right' 'mary_sigmoid_right' 'mary_sigmoid_right'
#  'mary_sigmoid_right' 'mary_sigmoid_right']

# %%
configuration['agg_strategy_imp']['strategy'] = 'fedmechw'
configuration['server_type'] = 'fedavg_pytorch'
configuration['prediction'] = False
configuration['save_state'] = True
configuration['track'] = True

configuration['algo_params']["fedmechw"] = {
    "client_thres": 0.4,
    "alpha": 1.0,
    "beta": 0
}

# Create Imputation Strategy
imp_strategy = configuration['agg_strategy_imp']['strategy']
params = configuration['algo_params'][imp_strategy]

strategy_imp = StrategyImputation(strategy=imp_strategy, params=params)

# Create Server
server_type = configuration['server_type']
server_config = configuration['server']
server_config["n_cols"] = test_data.shape[1] - 1

pred_config = configuration['pred_model']
pred_config['model_params']['input_feature_dim'] = test_data.shape[1] - 1
pred_config['model_params']['output_classes_dim'] = len(np.unique(test_data.iloc[:, -1].values))

server = load_server(
    server_type,
    clients=clients,
    strategy_imp=strategy_imp,
    server_config=server_config,
    pred_config=pred_config,
    test_data=test_data.values,
    seed=new_seed,
    track=configuration['track'],
    run_prediction=configuration['prediction'],
    persist_data=configuration['save_state'],
)

# return server
ret12 = server.run()
# Out:
# 2023-07-19 10:15:53.216 | INFO     | src.fed_imp.sub_modules.server.base_server:run:155 - FL finished in 104.08802470000228

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))
for client_id in client_ids:
    y = [ret12['client_imp_history'][i][2]['metrics'][client_id]['imp@rmse'] for i in x]
    ax.plot(x, y, label=client_id)
plt.show()

ret12['imp_result']
# Out:
# {'imp@rmse': 0.19964533072926968,
#  'imp@ws': 1.2664797670349441,
#  'imp@sliced_ws': 0.06620466545599235}

# %%
clients_ = {}
data_imp = ret12['data']['imputed_data']
missing_mask = ret12['data']['missing_mask']
data_true = ret12['data']['origin_data']
n_client = ret12['data']['origin_data'].shape[0]
test_data = ret12['data']['test_data']
for client_id in range(n_clients):
    clients_[client_id] = SimpleClient(
        client_id=client_id,
        data_imp=data_imp[client_id],
        missing_mask=missing_mask[client_id],
        data_true=data_true[client_id],
        data_test=test_data
    )

pred_config = server_config_tmpl.copy()
server_name = 'fedavg_mlp_pytorch_pred'
server_pred_config = pred_config['server_pred_config']
server_pred_config['train_params']['pred_round'] = 500
server_config = pred_config['server_config']
server_ = load_server(
        server_name, clients=clients_, server_config=server_config, pred_config=server_pred_config,
        test_data=test_data
    )

pred_ret8 = server_.prediction()
# Out:
# 2023-07-19 10:16:31.428 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 50, test_accu: 0.5978, test_f1: 0.5278, val_loss: 0.4120, val_accu: 0.8202, val_f1: 0.8201
# 2023-07-19 10:17:07.093 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 100, test_accu: 0.6108, test_f1: 0.5458, val_loss: 0.3640, val_accu: 0.8346, val_f1: 0.8345
# 2023-07-19 10:17:44.731 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 150, test_accu: 0.6123, test_f1: 0.5477, val_loss: 0.3509, val_accu: 0.8423, val_f1: 0.8421
# 2023-07-19 10:18:23.222 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 200, test_accu: 0.6040, test_f1: 0.5331, val_loss: 0.3423, val_accu: 0.8452, val_f1: 0.8451
# 2023-07-19 10:19:03.200 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 250, test_accu: 0.6100, test_f1: 0.5424, val_loss: 0.3396, val_accu: 0.8500, val_f1: 0.8498
# 2023-07-19 10:19:45.339 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 300, test_accu: 0.6054, test_f1: 0.5345, val_loss: 0.3365, val_accu: 0.8538, val_f1: 0.8537
# 2023-07-19 10:20:25.896 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 350, test_accu: 0.5991, test_f1: 0.5241, val_loss: 0.3345, val_accu: 0.8558, val_f1: 0.8556
# 2023-07-19 10:21:05.786 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 400, test_accu: 0.5937, test_f1: 0.5147, val_loss: 0.3358, val_accu: 0.8558, val_f1: 0.8556
# 2023-07-19 10:21:45.913 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:139 - Round: 450, test_accu: 0.5871, test_f1: 0.5035, val_loss: 0.3358, val_accu: 0.8596, val_f1: 0.8595
# 2023-07-19 10:22:06.755 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:154 - Early stop at round 475
# 2023-07-19 10:22:06.756 | INFO     | src.fed_imp.sub_modules.server.pred_server_fedavg_pytorch:prediction:164 - model1 test acc: 0.625916 (0.000), test f1: 0.591609 (0.000)

# %% [markdown]
# ## MARY Quantile

# %%
config = experiment_config_template.copy()
config['data']['dataset_name'] = 'statlog'
config['num_clients'] = 20
config['missing_simulate']['mr_strategy'] = 'fixed@mr=0.5'
config['missing_simulate']['mf_strategy'] = 'all'
config['missing_simulate']['mm_strategy'] = 'mary_lr@sp=extreme'
config['data_partition']['strategy'] = 'sample@p=0.01'

configuration = config
num_clients = configuration['num_clients']
# set random seed
seed = configuration['experiment']['seed']
mtp = configuration['experiment']['mtp']
tune_params = configuration['tune_params']
random.seed(seed)  # seed for split data

# load data
dataset_params = configuration['data']
data, data_config = load_data(**dataset_params)
regression = data_config['task_type'] == 'regression'

n_rounds = configuration['experiment']['n_rounds']
test_size = configuration['experiment'].get('test_size', 0.1)
if n_rounds == 1:
    n_rounds_data = split_train_test(data, n_folds=2, seed=seed, test_size=test_size, regression=regression)
else:
    n_rounds_data = split_train_test(
        data, n_folds=n_rounds, seed=seed, test_size=test_size, regression=regression
        )

# n rounds average
train_data, test_data = n_rounds_data[0]

new_seed = (seed + 10087 * 0) % (2 ^ 23)
regression = data_config['task_type'] == 'regression'
data_partition_params = configuration['data_partition']
data_partitions = data_partition(
    **data_partition_params, data=train_data.values, n_clients=num_clients, seed=new_seed,
    regression=regression
)
missing_params = configuration['missing_simulate']
cols = np.arange(0, train_data.shape[1] - 1)
scenario = missing_params
data_ms_clients = add_missing(
    train_data_list=data_partitions, scenario=scenario, cols=cols, seed=new_seed
)

client_factory = ClientsFactory(debug=False)
clients = client_factory.generate_clients(
    num_clients, data_partitions, data_ms_clients, test_data.values, data_config,
    configuration['imputation'], seed=new_seed
)
visualize_ms(data_ms_clients)
# Out:
# sample {'p': '0.01'}
# ['mary_left' 'mary_left' 'mary_right' 'mary_right' 'mary_right'
#  'mary_right' 'mary_right' 'mary_right' 'mary_right' 'mary_right'
#  'mary_right' 'mary_right' 'mary_right' 'mary_right' 'mary_right'
#  'mary_right' 'mary_right' 'mary_right' 'mary_right' 'mary_right']

# %% [markdown]
# ### Simple Averaging

# %%
configuration['agg_strategy_imp']['strategy'] = 'fedavg-s'
configuration['server_type'] = 'fedavg_pytorch'
configuration['prediction'] = False
configuration['save_state'] = True
configuration['track'] = True

# Create Imputation Strategy
imp_strategy = configuration['agg_strategy_imp']['strategy']
params = configuration['algo_params'][imp_strategy]

strategy_imp = StrategyImputation(strategy=imp_strategy, params=params)

# Create Server
server_type = configuration['server_type']
server_config = configuration['server']
server_config["n_cols"] = test_data.shape[1] - 1

pred_config = configuration['pred_model']
pred_config['model_params']['input_feature_dim'] = test_data.shape[1] - 1
pred_config['model_params']['output_classes_dim'] = len(np.unique(test_data.iloc[:, -1].values))

server = load_server(
    server_type,
    clients=clients,
    strategy_imp=strategy_imp,
    server_config=server_config,
    pred_config=pred_config,
    test_data=test_data.values,
    seed=new_seed,
    track=configuration['track'],
    run_prediction=configuration['prediction'],
    persist_data=configuration['save_state'],
)

# return server
ret13 = server.run()
# Out:
# 2023-07-19 12:33:04.183 | INFO     | src.fed_imp.sub_modules.server.base_server:run:155 - FL finished in 40.52946360001806

# %%
x = list(range(len(ret13['client_imp_history'])))
client_ids = list(ret13['client_imp_history'][0][2]['metrics'].keys())

fig, ax = plt.subplots(1, 1, figsize=(10, 5))
for client_id in client_ids:
    y = [ret13['client_imp_history'][i][2]['metrics'][client_id]['imp@rmse'] for i in x]
    ax.plot(x, y, label=client_id)
plt.show()

# %% [markdown]
# ### Complentary Models

# %%
configuration['agg_strategy_imp']['strategy'] = 'testavg2'
configuration['server_type'] = 'fedavg_pytorch'
configuration['prediction'] = False
configuration['save_state'] = True
configuration['track'] = True

# Create Imputation Strategy
imp_strategy = configuration['agg_strategy_imp']['strategy']
params = configuration['algo_params'][imp_strategy]

strategy_imp = StrategyImputation(strategy=imp_strategy, params=params)

# Create Server
server_type = configuration['server_type']
server_config = configuration['server']
server_config["n_cols"] = test_data.shape[1] - 1

pred_config = configuration['pred_model']
pred_config['model_params']['input_feature_dim'] = test_data.shape[1] - 1
pred_config['model_params']['output_classes_dim'] = len(np.unique(test_data.iloc[:, -1].values))

server = load_server(
    server_type,
    clients=clients,
    strategy_imp=strategy_imp,
    server_config=server_config,
    pred_config=pred_config,
    test_data=test_data.values,
    seed=new_seed,
    track=configuration['track'],
    run_prediction=configuration['prediction'],
    persist_data=configuration['save_state'],
)

# return server
ret14 = server.run()
# Out:
# testavg2
# 2023-07-19 12:33:42.875 | INFO     | src.fed_imp.sub_modules.server.base_server:run:155 - FL finished in 38.507185700000264

# %%
x = list(range(len(ret14['client_imp_history'])))
client_ids = list(ret14['client_imp_history'][0][2]['metrics'].keys())

fig, ax = plt.subplots(1, 1, figsize=(10, 5))
for client_id in client_ids:
    y = [ret14['client_imp_history'][i][2]['metrics'][client_id]['imp@rmse'] for i in x]
    ax.plot(x, y, label=client_id)
plt.show()

# %% [markdown]
# ## MARY RL

# %%
config = experiment_config_template.copy()
config['data']['dataset_name'] = 'statlog'
config['num_clients'] = 20
config['missing_simulate']['mr_strategy'] = 'fixed@mr=0.5'
config['missing_simulate']['mf_strategy'] = 'all'
config['missing_simulate']['mm_strategy'] = 'mary_sigmoid_rl@sp=extreme'
config['data_partition']['strategy'] = 'sample@p=0.01'

configuration = config
num_clients = configuration['num_clients']
# set random seed
seed = configuration['experiment']['seed']
mtp = configuration['experiment']['mtp']
tune_params = configuration['tune_params']
random.seed(seed)  # seed for split data

# load data
dataset_params = configuration['data']
data, data_config = load_data(**dataset_params)
regression = data_config['task_type'] == 'regression'

n_rounds = configuration['experiment']['n_rounds']
test_size = configuration['experiment'].get('test_size', 0.1)
if n_rounds == 1:
    n_rounds_data = split_train_test(data, n_folds=2, seed=seed, test_size=test_size, regression=regression)
else:
    n_rounds_data = split_train_test(
        data, n_folds=n_rounds, seed=seed, test_size=test_size, regression=regression
        )

# n rounds average
train_data, test_data = n_rounds_data[0]

new_seed = (seed + 10087 * 0) % (2 ^ 23)
regression = data_config['task_type'] == 'regression'
data_partition_params = configuration['data_partition']
data_partitions = data_partition(
    **data_partition_params, data=train_data.values, n_clients=num_clients, seed=new_seed,
    regression=regression
)
missing_params = configuration['missing_simulate']
cols = np.arange(0, train_data.shape[1] - 1)
scenario = missing_params
data_ms_clients = add_missing(
    train_data_list=data_partitions, scenario=scenario, cols=cols, seed=new_seed
)

client_factory = ClientsFactory(debug=False)
clients = client_factory.generate_clients(
    num_clients, data_partitions, data_ms_clients, test_data.values, data_config,
    configuration['imputation'], seed=new_seed
)
visualize_ms(data_ms_clients)
# Out:
# sample {'p': '0.01'}
# ['mary_sigmoid_right' 'mary_sigmoid_right' 'mary_sigmoid_left'
#  'mary_sigmoid_left' 'mary_sigmoid_left' 'mary_sigmoid_left'
#  'mary_sigmoid_left' 'mary_sigmoid_left' 'mary_sigmoid_left'
#  'mary_sigmoid_left' 'mary_sigmoid_left' 'mary_sigmoid_left'
#  'mary_sigmoid_left' 'mary_sigmoid_left' 'mary_sigmoid_left'
#  'mary_sigmoid_left' 'mary_sigmoid_left' 'mary_sigmoid_left'
#  'mary_sigmoid_left' 'mary_sigmoid_left']

# %% [markdown]
# ### Simple Averaging

# %%
configuration['agg_strategy_imp']['strategy'] = 'fedavg-s'
configuration['server_type'] = 'fedavg_pytorch'
configuration['prediction'] = False
configuration['save_state'] = True
configuration['track'] = True

# Create Imputation Strategy
imp_strategy = configuration['agg_strategy_imp']['strategy']
params = configuration['algo_params'][imp_strategy]

strategy_imp = StrategyImputation(strategy=imp_strategy, params=params)

# Create Server
server_type = configuration['server_type']
server_config = configuration['server']
server_config["n_cols"] = test_data.shape[1] - 1

pred_config = configuration['pred_model']
pred_config['model_params']['input_feature_dim'] = test_data.shape[1] - 1
pred_config['model_params']['output_classes_dim'] = len(np.unique(test_data.iloc[:, -1].values))

server = load_server(
    server_type,
    clients=clients,
    strategy_imp=strategy_imp,
    server_config=server_config,
    pred_config=pred_config,
    test_data=test_data.values,
    seed=new_seed,
    track=configuration['track'],
    run_prediction=configuration['prediction'],
    persist_data=configuration['save_state'],
)

# return server
ret15 = server.run()
# Out:
# 2023-07-19 12:34:25.994 | INFO     | src.fed_imp.sub_modules.server.base_server:run:155 - FL finished in 38.956121499999426

# %%
x = list(range(len(ret15['client_imp_history'])))
client_ids = list(ret15['client_imp_history'][0][2]['metrics'].keys())

fig, ax = plt.subplots(1, 1, figsize=(10, 5))
for client_id in client_ids:
    y = [ret15['client_imp_history'][i][2]['metrics'][client_id]['imp@rmse'] for i in x]
    ax.plot(x, y, label=client_id)
plt.show()

# %% [markdown]
# ### Complementary Models

# %%
configuration['agg_strategy_imp']['strategy'] = 'testavg2'
configuration['server_type'] = 'fedavg_pytorch'
configuration['prediction'] = False
configuration['save_state'] = True
configuration['track'] = True

# Create Imputation Strategy
imp_strategy = configuration['agg_strategy_imp']['strategy']
params = configuration['algo_params'][imp_strategy]

strategy_imp = StrategyImputation(strategy=imp_strategy, params=params)

# Create Server
server_type = configuration['server_type']
server_config = configuration['server']
server_config["n_cols"] = test_data.shape[1] - 1

pred_config = configuration['pred_model']
pred_config['model_params']['input_feature_dim'] = test_data.shape[1] - 1
pred_config['model_params']['output_classes_dim'] = len(np.unique(test_data.iloc[:, -1].values))

server = load_server(
    server_type,
    clients=clients,
    strategy_imp=strategy_imp,
    server_config=server_config,
    pred_config=pred_config,
    test_data=test_data.values,
    seed=new_seed,
    track=configuration['track'],
    run_prediction=configuration['prediction'],
    persist_data=configuration['save_state'],
)

# return server
ret16 = server.run()
# Out:
# testavg2
# 2023-07-19 12:35:04.920 | INFO     | src.fed_imp.sub_modules.server.base_server:run:155 - FL finished in 38.704991000005975

# %%
x = list(range(len(ret16['client_imp_history'])))
client_ids = list(ret16['client_imp_history'][0][2]['metrics'].keys())

fig, ax = plt.subplots(1, 1, figsize=(10, 5))
for client_id in client_ids:
    y = [ret16['client_imp_history'][i][2]['metrics'][client_id]['imp@rmse'] for i in x]
    ax.plot(x, y, label=client_id)
plt.show()
