# %%
cd ..
# Out:
# m:\research\federated_imputation

# %%
import pandas as pd
from src.modules.data_prep_utils import (
	convert_gaussian, normalization, drop_unique_cols, one_hot_categorical, move_target_to_end,
)

# %%
data = pd.read_csv("./data/codon/codon_usage.csv", sep=',', low_memory=False)
data = data.dropna()
#data.columns = [str(i) for i in range(data.sh
data = data.drop(['SpeciesID', 'Ncodons', 'SpeciesName', 'DNAtype'], axis=1)
target_col = 'Kingdom'
data = data[data[target_col] != 'plm']
data[target_col], codes = pd.factorize(data[target_col])
data = data.replace("non-B hepatitis virus", 0)
data = data.replace("12;I", 1)
data = data.replace('-', 0)
data = move_target_to_end(data, target_col)
data = normalization(data, target_col)

# %%
data
# Out:
#        Kingdom      UUU      UUC      UUA      UUG      CUU      CUC      CUA
# 0            0  0.01654  0.01203  0.00050  0.00351  0.01203  0.03208  0.00100  \
# 1            0  0.02714  0.01357  0.00068  0.00678  0.00407  0.02849  0.00204
# 2            0  0.01974   0.0218  0.01357  0.01543  0.00782  0.01111  0.01028
# 3            0  0.01775  0.02245  0.01619  0.00992  0.01567  0.01358  0.00940
# 4            0  0.02816  0.01371  0.00767  0.03679  0.01380  0.00548  0.00473
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 13023        9  0.02552  0.03555  0.00547  0.01367  0.01276  0.02097  0.00820
# 13024        9  0.01258  0.03193  0.01984  0.00629  0.01451  0.05322  0.07644
# 13025        9  0.01423  0.03321  0.01661  0.00356  0.01127  0.05042  0.09609
# 13026        9  0.01757  0.02028  0.00767  0.01293  0.01319  0.01959  0.00715
# 13027        9  0.01778  0.03724  0.01732  0.00600  0.01689  0.03854  0.07000
#
#            CUG      AUU  ...      CGG      AGA      AGG      GAU      GAC
# 0      0.04010  0.00551  ...  0.00451  0.01303  0.03559  0.01003  0.04612  \
# 1      0.04410  0.01153  ...  0.00136  0.01696  0.03596  0.01221  0.04545
# 2      0.01193  0.02283  ...  0.00596  0.01974  0.02489  0.03126  0.02036
# 3      0.01723  0.02402  ...  0.00366  0.01410  0.01671  0.03760  0.01932
# 4      0.02076  0.02716  ...  0.00604  0.01494  0.01734  0.04148  0.02483
# ...        ...      ...  ...      ...      ...      ...      ...      ...
# 13023  0.03555  0.01459  ...  0.00820  0.01367  0.01094  0.01367  0.02279
# 13024  0.01258  0.03096  ...  0.00145  0.00000  0.00048  0.00194  0.01306
# 13025  0.01068  0.02728  ...  0.00000  0.00000  0.00000  0.00178  0.01661
# 13026  0.03964  0.01600  ...  0.01142  0.01217  0.01196  0.02178  0.02510
# 13027  0.01308  0.03391  ...  0.00083  0.00041  0.00041  0.00451  0.01402
#
#            GAA      GAG      UAA      UAG      UGA
# 0      0.01203  0.04361  0.00251  0.00050  0.00000
# 1      0.01560  0.04410  0.00271  0.00068  0.00000
# 2      0.02242  0.02468  0.00391  0.00000  0.00144
# 3      0.03029  0.03446  0.00261  0.00157  0.00000
# 4      0.03359  0.03679  0.00000  0.00044  0.00131
# ...        ...      ...      ...      ...      ...
# 13023  0.02005  0.04102  0.00091  0.00091  0.00638
# 13024  0.01838  0.00677  0.00242  0.00097  0.01887
# 13025  0.02788  0.00297  0.00356  0.00119  0.02017
# 13026  0.02896  0.03959  0.00099  0.00079  0.00156
# 13027  0.01651  0.00783  0.00156  0.00114  0.02161
#
# [13010 rows x 65 columns]
